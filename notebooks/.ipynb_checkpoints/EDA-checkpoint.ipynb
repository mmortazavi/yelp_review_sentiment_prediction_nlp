# %% [markdown]
# # Yelp Reveiw Analysis

# %%
# %load_ext autoreload
# %autoreload 2

# %%
## standard libs
import pandas as pd
import re
import numpy as np
import seaborn as sns
import nltk
import string
from nltk.corpus import stopwords
import string
import operator 
import math
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from tqdm import tqdm

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
## cutome modules
from yelp.data import read_json_to_df
from yelp.utils import get_text_lengh
from yelp.utils import target_binning
from yelp.utils import plot_mean_frequency
from yelp.utils import get_bayesian_estimates
from yelp.utils import top_businesses
from yelp.preprocessing import text_clean
from yelp.preprocessing import get_wordcloud
from yelp.preprocessing import tokenize

tqdm.pandas()

# %matplotlib inline

# %% [markdown]
# ## Data

# %%
DATA_PATH = '/Users/majidmortazavi/data_sciences/case_studies/NewYorker/data/'
DATA_FILE = 'review.json'

df = read_json_to_df(DATA_PATH, DATA_FILE, chunksize = 1000)

# %%
df.head(2)
# Out:
#               business_id  cool                date  funny  \
# 0  ujmEBvifdJM6h6RLv4wQIg     0 2013-05-07 04:34:36      1
# 1  NZnhc2sEQy3RmzKTZnqtwQ     0 2017-01-14 21:30:33      0
#
#                 review_id  stars  \
# 0  Q1sbwvVQXV2734tPgoKj4Q      1
# 1  GJXCdrto3ASJOqKeVWPi6Q      5
#
#                                                 text  useful  \
# 0  Total bill for this horrible service? Over $8G...       6
# 1  I *adore* Travis at the Hard Rock's new Kelly ...       0
#
#                   user_id
# 0  hG7b0MtEbXx5QzbzE6C_VA
# 1  yXQM5uF2jS6es16SJzNHfg

# %% [markdown]
# ## Features

# %%
df['clean_text'] = df['text'].apply(lambda tx: text_clean(tx))

# %%
df = target_binning(df)

# %%
df['text_length'] = df['text'].apply(len)
df['clean_text_length'] = df['clean_text'].apply(len)

# %%
df.head(4)
# Out:
#               business_id  cool                date  funny  \
# 0  ujmEBvifdJM6h6RLv4wQIg     0 2013-05-07 04:34:36      1
# 1  NZnhc2sEQy3RmzKTZnqtwQ     0 2017-01-14 21:30:33      0
# 2  WTqjgwHlXbSFevF32_DJVw     0 2016-11-09 20:09:03      0
# 3  ikCg8xy5JIg_NGPx-MSIDA     0 2018-01-09 20:56:38      0
#
#                 review_id  stars  \
# 0  Q1sbwvVQXV2734tPgoKj4Q      1
# 1  GJXCdrto3ASJOqKeVWPi6Q      5
# 2  2TzJjDVDEuAW6MR5Vuc1ug      5
# 3  yi0R0Ugj_xUx_Nek0-_Qig      5
#
#                                                 text  useful  \
# 0  Total bill for this horrible service? Over $8G...       6
# 1  I *adore* Travis at the Hard Rock's new Kelly ...       0
# 2  I have to say that this office really has it t...       3
# 3  Went in for a lunch. Steak sandwich was delici...       0
#
#                   user_id                                         clean_text  \
# 0  hG7b0MtEbXx5QzbzE6C_VA  Total bill horrible service 8Gs crooks actuall...
# 1  yXQM5uF2jS6es16SJzNHfg  adore Travis Hard Rocks new Kelly Cardenas Sal...
# 2  n6-Gk65cPZL6Uz8qRm3NYw  say office really together organized friendly ...
# 3  dacAIZ6fTM6mqwW5uxkskg  Went lunch Steak sandwich delicious Caesar sal...
#
#      labels  text_length  clean_text_length
# 0  Negative          204                121
# 1  Positive         1561               1046
# 2  Positive          615                359
# 3  Positive          407                270

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Text Lenght vs Stars

# %%
graph = sns.FacetGrid(data=df,col='stars')
graph.map(plt.hist,'text_length',bins=50,color='blue');

# %%
graph = sns.FacetGrid(data=df,col='stars')
graph.map(plt.hist,'clean_text_length',bins=50,color='blue');

# %% [markdown]
# ### Mean of Variables vs. Stars

# %%
eval_cols = ['stars', 'cool','funny', 'useful', 'text_length']
df.groupby('stars')[eval_cols[1:]].mean()
# Out:
#            cool     funny    useful  text_length
# stars
# 1      0.148387  0.412903  1.819355   796.812903
# 2      0.406593  0.769231  1.901099   837.780220
# 3      0.834862  0.623853  1.577982   801.055046
# 4      0.731915  0.425532  1.140426   653.017021
# 5      0.490244  0.365854  0.917073   517.478049

# %%
eval_cols = ['stars', 'cool','funny', 'useful', 'text_length']
df.groupby('labels')[eval_cols[1:]].mean()
# Out:
#               cool     funny    useful  text_length
# labels
# Negative  0.425352  0.569014  1.766197   808.616901
# Positive  0.578295  0.387597  0.998450   566.860465

# %% [markdown]
# ### Correlation of Mean of Variables

# %%
eval_cols = ['stars', 'cool','funny', 'useful', 'text_length', 'clean_text_length']
cor_data = df.groupby('stars')[eval_cols[1:]].mean()

cor_data.corr()
# Out:
#                        cool     funny    useful  text_length  \
# cool               1.000000  0.154799 -0.425171    -0.168491
# funny              0.154799  1.000000  0.674218     0.731680
# useful            -0.425171  0.674218  1.000000     0.959937
# text_length       -0.168491  0.731680  0.959937     1.000000
# clean_text_length -0.077277  0.747549  0.929240     0.995388
#
#                    clean_text_length
# cool                       -0.077277
# funny                       0.747549
# useful                      0.929240
# text_length                 0.995388
# clean_text_length           1.000000

# %% [markdown]
# ### Mean against the Number of Reviews

# %%
plot_mean_frequency(df)

# %% [markdown]
# ### Mean, Count and Bayesian Estimation of Stars

# %%
top_businesses(df)
# Out:
#                             mean  count     bayes
# business_id
# FBSWwaE6gR7KAOyG1QhakQ  5.000000      2  3.317308
# fbQaKW0Lte0JQ_opbnjdKg  5.000000      2  3.317308
# yKaIT0fnxEj0YVr1DMHvuQ  5.000000      2  3.317308
# faPVqws-x-5k2CQKDNtHxw  5.000000      2  3.317308
# CGUK3cd2gxp2q3KPY19Oog  5.000000      2  3.317308
# Wxxvi3LZbHNIDwJ-ZimtnA  3.636364     11  3.319672
# qQCsLGMncJp1xWUGnOKCQA  5.000000      3  3.349057
# eTXYID00jGxq1vZpntBUFw  5.000000      3  3.349057
# LUN6swQYa4xJKaM_UEUOEw  4.750000      4  3.361111
# SVGApDPNdpFlEjwRQThCxA  4.666667      6  3.401786

# %% [markdown]
# ### Stars [1, 5, 4, 3, 2] Histogram

# %%
df['stars'].hist();

# %%
df['labels'].value_counts()
# Out:
# Positive    645
# Negative    355
# Name: labels, dtype: int64

# %% [markdown]
# ## WordCloud

# %%
data['tok_text'] = data['text'].progress_apply(lambda mu: word_tokenize(mu))
# Out:
# 100%|██████████| 66859/66859 [00:48<00:00, 1368.34it/s]

# %%
data['norm_sentence_list'] = data['tok_text'].progress_apply(lambda mu: normalize(mu))
# Out:
# 100%|██████████| 66859/66859 [09:56<00:00, 112.08it/s]

# %%
data['norm_sentence'] = data['norm_sentence_list'].progress_apply(lambda mu: ' '.join(mu))
# Out:
# 100%|██████████| 66859/66859 [00:00<00:00, 591880.31it/s]

# %%
get_wordcloud(df, col_to_plot='processed_text', target='All', show=True)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# INFO:root:
# Unfortunately, your original traceback can not be constructed.
# Traceback (most recent call last):
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-35-15e1cbe8b7dc>", line 1, in <module>
#     get_wordcloud(data, col_to_plot='processed_text', target='All', show=True)
#   File "/Users/majidmortazavi/data_sciences/case_studies/new_yorker/yelp/preprocessing.py", line 174, in get_wordcloud
#     background_color=background_color).generate(all_words)
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/site-packages/wordcloud/wordcloud.py", line 556, in generate
#     return self.generate_from_text(text)
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/site-packages/wordcloud/wordcloud.py", line 541, in generate_from_text
#     words = self.process_text(text)
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/site-packages/wordcloud/wordcloud.py", line 522, in process_text
#     word_counts = unigrams_and_bigrams(words, self.normalize_plurals)
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/site-packages/wordcloud/tokenization.py", line 46, in unigrams_and_bigrams
#     normalize_plurals=normalize_plurals)
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/site-packages/wordcloud/tokenization.py", line 108, in process_tokens
#     case_dict[word] = case_dict.get(word, 0) + 1
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/inspect.py", line 1488, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/inspect.py", line 1446, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/majidmortazavi/anaconda3/lib/python3.6/inspect.py", line 732, in getmodule
#     for modname, module in list(sys.modules.items()):
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
get_wordcloud(data,  target='All', show=True)
get_wordcloud(data,  target=1, show=True)
get_wordcloud(data,  target=3, show=True)
get_wordcloud(data,  target=5, show=True)
